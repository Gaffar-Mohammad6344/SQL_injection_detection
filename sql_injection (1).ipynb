# %%
# !pip install numpy

# %%
# !pip install gensim
# Out:
# ...
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
#   Using cached scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# ...
# Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# Using cached scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.4
#     Uninstalling numpy-2.2.4:
#       Successfully uninstalled numpy-2.2.4
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.2
#     Uninstalling scipy-1.15.2:
#       Successfully uninstalled scipy-1.15.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# ...

# %%
# !pip uninstall -y numpy gensim
# !pip install --no-cache-dir numpy gensim
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Found existing installation: gensim 4.3.3
# Uninstalling gensim-4.3.3:
#   Successfully uninstalled gensim-4.3.3
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 14.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 249.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 328.4 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# ...

# %%
# !pip install spacy
# !python -m spacy download en_core_web_md
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.5/33.5 MB 10.2 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# !pip install tensorflow

# %%
# !pip uninstall -y numpy pandas
# !pip install numpy
# !pip install pandas
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Found existing installation: pandas 2.2.3
# Uninstalling pandas-2.2.3:
#   Successfully uninstalled pandas-2.2.3
# ...
#   Using cached numpy-2.2.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Using cached numpy-2.2.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# catboost 1.2.7 requires pandas>=0.24, which is not installed.
# fastai 2.7.19 requires pandas, which is not installed.
# seaborn 0.13.2 requires pandas>=1.2, which is not installed.
# sklearn-pandas 2.2.0 requires pandas>=1.1.4, which is not installed.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.2.4 which is incompatible.
# ...

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
import pandas as pd

# %%
# Download both 'punkt' and 'punkt_tab'
nltk.download('punkt')
nltk.download('punkt_tab')  # Download the missing 'punkt_tab' resource

# Load dataset
df = pd.read_csv("/content/sql_injection_dataset.csv")

# Normalization function
def normalize_query(query):
    query = query.lower()  # Convert to lowercase
    query = re.sub(r"[^a-zA-Z0-9]", " ", query)  # Remove special characters
    return query

# Apply normalization
df["cleaned_query"] = df["Query"].apply(normalize_query)

# Tokenization
df["tokens"] = df["cleaned_query"].apply(word_tokenize)

# Save processed data
df.to_csv("processed_dataset.csv", index=False)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# Download both 'punkt' and 'punkt_tab'
nltk.download('punkt')
nltk.download('punkt_tab')  # Download the missing 'punkt_tab' resource

# Load dataset
df = pd.read_csv("/content/sql_injection_dataset.csv")

# Normalization function
def normalize_query(query):
    query = query.lower()  # Convert to lowercase
    query = re.sub(r"[^a-zA-Z0-9]", " ", query)  # Remove special characters
    return query

# Apply normalization
df["cleaned_query"] = df["Query"].apply(normalize_query)

# Tokenization
df["tokens"] = df["cleaned_query"].apply(word_tokenize)

# Save processed data
df.to_csv("processed_dataset.csv", index=False)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
import pandas as pd
import numpy as np
import pickle
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Load dataset
df = pd.read_csv("/content/sql_injection_dataset.csv")

# Assuming 'Query' column has SQL queries
queries = df["Query"].astype(str).tolist()

# Tokenizer setup
MAX_VOCAB_SIZE = 10000  # Set vocab size
MAX_SEQUENCE_LENGTH = 100  # Max length of a sequence

tokenizer = Tokenizer(num_words=MAX_VOCAB_SIZE, oov_token="<OOV>")
tokenizer.fit_on_texts(queries)

# Convert text to sequences
sequences = tokenizer.texts_to_sequences(queries)

# Apply padding to ensure uniform length
padded_sequences = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH, padding="post")

# Save Tokenizer for later use
with open("tokenizer.pkl", "wb") as f:
    pickle.dump(tokenizer, f)

# Save processed data as NumPy array
np.save("sql_padded_sequences.npy", padded_sequences)

print(f"Tokenized and padded dataset shape: {padded_sequences.shape}")
# Out:
# Tokenized and padded dataset shape: (30919, 100)

# %%
# !pip install catboost
# Out:
# ...
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
# Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.4
#     Uninstalling numpy-2.2.4:
#       Successfully uninstalled numpy-2.2.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# ...

# %%
# !pip install git+https://github.com/facebookresearch/fastText.git
# Out:
# ...
#   Cloning https://github.com/facebookresearch/fastText.git to /tmp/pip-req-build-y0040tq5
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/fastText.git /tmp/pip-req-build-y0040tq5
#   Resolved https://github.com/facebookresearch/fastText.git to commit 1142dc4c4ecbc19cc16eee5cdd28472e689267e6
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !pip install wheel setuptools numpy scipy scikit-learn

# %%
# !pip install fasttext-wheel

# %%
import fasttext

# Assuming you've uploaded 'sql_data.txt' to '/content/'
# If it's in a different location, adjust the path accordingly
file_path = '/content/sql_data.txt'

# Check if the file exists
import os
if not os.path.exists(file_path):
    print(f"Error: File not found at {file_path}")
    # Handle file upload or error here (e.g., download, ask user to upload)
else:
    # Train the FastText model
    model = fasttext.train_unsupervised(file_path, model='skipgram')

    # Get word vector
    vector = model.get_word_vector("injection")
    print(vector)
# Out:
# Error: File not found at /content/sql_data.txt

# %%
import spacy

nlp = spacy.load("en_core_web_md")  # Load medium-sized word embeddings
word_vector = nlp("injection").vector
print(word_vector)
# Out:
# [-0.61721   0.62113  -0.3699   -0.0835   -0.91292  -0.2796   -0.89662
#   0.1076    0.2506    0.47763  -0.53459   0.22233  -0.48481   0.67175
#   1.1125    0.015559  0.26401   2.1954    0.24814   0.31459  -0.41842
#   0.036809 -0.43053  -0.49003  -0.25273  -0.30245   0.38716  -0.62239
#   0.99508   0.14893  -0.33058  -0.061682  0.19126   0.31497  -0.16694
#   0.51194  -0.3884   -0.36756  -0.26294   0.39966   0.30036  -0.58009
#  -0.013378  0.17101  -0.042521 -0.53452  -0.41239  -0.047397  0.14183
#  -0.16304  -0.12683   0.25132  -0.43579  -0.12212   0.45777   0.49899
#   0.404    -0.40161  -0.41003  -0.46823   0.26705   0.12223   0.63153
#   0.66171   0.12883   0.27334   0.038646  0.19017  -0.22311  -0.13465
#  -0.18316  -0.40761   0.59861  -0.079749  0.8205   -0.03868   0.33989
#  -0.52478   0.18461  -0.11773   0.2825   -0.58476  -0.66726   0.77946
#  -0.20782  -0.53035   0.97206  -0.47363  -0.014709  0.59342  -0.035735
# ...

# %%
from tensorflow.keras.layers import Embedding
import numpy as np

# Sample vocab size and embedding dimensions
vocab_size = 5000
embedding_dim = 100

embedding_layer = Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=50)

# Random word index example
word_index = np.array([[1, 45, 23, 67, 89]])
embedded_output = embedding_layer(word_index)
print(embedded_output.shape)
# Out:
# (1, 5, 100)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Tokenize the queries
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts(df["Query"])

# Convert text to sequences
sequences = tokenizer.texts_to_sequences(df["Query"])

# Pad sequences to ensure uniform length
max_length = 50  # Set according to dataset analysis
padded_sequences = pad_sequences(sequences, maxlen=max_length, padding="post")

# Convert labels to numpy array
labels = np.array(df["Label"])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dense, Dropout, Bidirectional

# Build model
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_length),
    Bidirectional(LSTM(64, return_sequences=True)),
    Dropout(0.3),
    GRU(32),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')  # Binary classification (0 = normal, 1 = attack)
])

# Compile model
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)              │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru (GRU)                            │ ?                           │     0 (unbuilt) │
# ...

# %%
# !pip uninstall -y numpy scipy scikit-learn
# !pip install --no-cache-dir numpy scipy scikit-learn
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Found existing installation: scipy 1.13.1
# Uninstalling scipy-1.13.1:
#   Successfully uninstalled scipy-1.13.1
# Found existing installation: scikit-learn 1.6.1
# Uninstalling scikit-learn-1.6.1:
#   Successfully uninstalled scikit-learn-1.6.1
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 15.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 286.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 262.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 272.6 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# Split dataset (80% train, 20% test)
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(padded_sequences, labels, test_size=0.2, random_state=42)

# Train the model
model.fit(X_train, y_train, epochs=5, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/5
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 59s 69ms/step - accuracy: 0.8922 - loss: 0.2637 - val_accuracy: 0.9851 - val_loss: 0.0549
# Epoch 2/5
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 48s 62ms/step - accuracy: 0.9939 - loss: 0.0285 - val_accuracy: 0.9945 - val_loss: 0.0289
# Epoch 3/5
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 49s 63ms/step - accuracy: 0.9959 - loss: 0.0211 - val_accuracy: 0.9951 - val_loss: 0.0239
# Epoch 4/5
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 49s 64ms/step - accuracy: 0.9968 - loss: 0.0160 - val_accuracy: 0.9945 - val_loss: 0.0200
# Epoch 5/5
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 48s 62ms/step - accuracy: 0.9975 - loss: 0.0127 - val_accuracy: 0.9924 - val_loss: 0.0264

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.2f}")
# Out:
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9911 - loss: 0.0289
# Test Accuracy: 0.99

# %%
# Tokenization
tokenizer = Tokenizer(num_words=10000, oov_token="<OOV>")
tokenizer.fit_on_texts(df["Query"])
sequences = tokenizer.texts_to_sequences(df["Query"])
padded_sequences = pad_sequences(sequences, maxlen=50, padding="post")

# Split data
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, df["Label"], test_size=0.2, random_state=42)

# Convert labels to numpy arrays
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
rnn_model = tf.keras.Sequential([
    tf.keras.layers.Embedding(input_dim=10000, output_dim=128, input_length=50),
    tf.keras.layers.SimpleRNN(64, return_sequences=True),
    tf.keras.layers.SimpleRNN(32),
    tf.keras.layers.Dense(32, activation="relu"),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

rnn_model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
rnn_model.fit(X_train, y_train, epochs=5, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/5
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 36s 42ms/step - accuracy: 0.9579 - loss: 0.1304 - val_accuracy: 0.9906 - val_loss: 0.0424
# Epoch 2/5
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 32s 42ms/step - accuracy: 0.9939 - loss: 0.0268 - val_accuracy: 0.9919 - val_loss: 0.0305
# Epoch 3/5
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9904 - loss: 0.0349 - val_accuracy: 0.9334 - val_loss: 0.2232
# Epoch 4/5
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 32s 42ms/step - accuracy: 0.9519 - loss: 0.1581 - val_accuracy: 0.9766 - val_loss: 0.0965
# Epoch 5/5
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 32s 42ms/step - accuracy: 0.9827 - loss: 0.0712 - val_accuracy: 0.9882 - val_loss: 0.0515

# %%
lstm_model = tf.keras.Sequential([
    tf.keras.layers.Embedding(input_dim=10000, output_dim=128, input_length=50),
    tf.keras.layers.LSTM(64, return_sequences=True),
    tf.keras.layers.LSTM(32),
    tf.keras.layers.Dense(32, activation="relu"),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

lstm_model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
lstm_model.fit(X_train, y_train, epochs=5, batch_size=32, validation_data=(X_test, y_test))
# Out:
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 45s 54ms/step - accuracy: 0.6526 - loss: 0.6345 - val_accuracy: 0.6295 - val_loss: 0.6328
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 45s 54ms/step - accuracy: 0.6526 - loss: 0.6345 - val_accuracy: 0.6295 - val_loss: 0.6328
# Epoch 2/5
# Epoch 2/5
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 41s 54ms/step - accuracy: 0.6320 - loss: 0.6330 - val_accuracy: 0.6295 - val_loss: 0.6330
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 41s 54ms/step - accuracy: 0.6320 - loss: 0.6330 - val_accuracy: 0.6295 - val_loss: 0.6330
# Epoch 3/5
# Epoch 3/5
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.6296 - loss: 0.6354 - val_accuracy: 0.6295 - val_loss: 0.6331
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.6296 - loss: 0.6354 - val_accuracy: 0.6295 - val_loss: 0.6331
# Epoch 4/5
# Epoch 4/5
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.6281 - loss: 0.6363 - val_accuracy: 0.6295 - val_loss: 0.6327
# ...

# %%
gru_model = tf.keras.Sequential([
    tf.keras.layers.Embedding(input_dim=10000, output_dim=128, input_length=50),
    tf.keras.layers.GRU(64, return_sequences=True),
    tf.keras.layers.GRU(32),
    tf.keras.layers.Dense(32, activation="relu"),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

gru_model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
gru_model.fit(X_train, y_train, epochs=5, batch_size=32, validation_data=(X_test, y_test))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, Dense, Embedding
from sklearn.model_selection import train_test_split # Import train_test_split

vocab_size = 10000
sequence_length = 50
embedding_dim = 128

def create_cnn_model():
    model = Sequential([
        Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=sequence_length),
        Conv1D(filters=64, kernel_size=3, activation='relu', padding='same'),
        MaxPooling1D(pool_size=2),
        Conv1D(filters=32, kernel_size=3, activation='relu', padding='same'),
        GlobalMaxPooling1D(),
        Dense(16, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Save the model after training
cnn_model = create_cnn_model()

# Split data into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42) # Create validation set

cnn_model.fit(X_train, y_train, epochs=5, batch_size=32, validation_data=(X_val, y_val))
cnn_model.save("cnn_model.h5")
# Out:
# Epoch 1/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 22s 33ms/step - accuracy: 0.9134 - loss: 0.1834 - val_accuracy: 0.9962 - val_loss: 0.0135
# Epoch 2/5
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - accuracy: 0.9970 - loss: 0.0117 - val_accuracy: 0.9976 - val_loss: 0.0153
# Epoch 3/5
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - accuracy: 0.9988 - loss: 0.0063 - val_accuracy: 0.9974 - val_loss: 0.0150
# Epoch 4/5
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - accuracy: 0.9989 - loss: 0.0069 - val_accuracy: 0.9980 - val_loss: 0.0142
# Epoch 5/5
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - accuracy: 0.9989 - loss: 0.0071 - val_accuracy: 0.9980 - val_loss: 0.0135
# ...

# %%
def ensemble_predict(models, X):
    predictions = np.array([model.predict(X) for model in models])
    avg_prediction = np.mean(predictions, axis=0)
    return (avg_prediction > 0.5).astype(int)

models = [rnn_model, lstm_model, gru_model, cnn_model]
y_pred_ensemble = ensemble_predict(models, X_test)

from sklearn.metrics import accuracy_score
ensemble_accuracy = accuracy_score(y_test, y_pred_ensemble)
print("Ensemble Model Accuracy:", ensemble_accuracy)

# %%
# !pip install transformers

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=200, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
# !pip install xgboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.9/253.9 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 5.0 MB/s eta 0:00:00
# ...

# %%
from xgboost import XGBClassifier

xgb_model = XGBClassifier(n_estimators=200, learning_rate=0.05, max_depth=6, random_state=42)
xgb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
# !pip install lightgbm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 35.4 MB/s eta 0:00:00
# ...

# %%
from lightgbm import LGBMClassifier
lgb_model = LGBMClassifier(n_estimators=200, learning_rate=0.05, max_depth=6, random_state=42)
lgb_model.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Number of positive: 7259, number of negative: 12529
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003497 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6078
# [LightGBM] [Info] Number of data points in the train set: 19788, number of used features: 50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.366838 -> initscore=-0.545804
# [LightGBM] [Info] Start training from score -0.545804
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
# !pip uninstall -y numpy catboost
# !pip install --no-cache-dir numpy catboost

# %%
from sklearn.ensemble import VotingClassifier

ensemble_model = VotingClassifier(
    estimators=[
        ('Random Forest', rf_model),
        ('XGBoost', xgb_model),
        ('LightGBM', lgb_model),
    ],
    voting='soft'  # 'soft' uses probabilities for better accuracy
)

ensemble_model.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Number of positive: 7259, number of negative: 12529
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002802 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6078
# [LightGBM] [Info] Number of data points in the train set: 19788, number of used features: 50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.366838 -> initscore=-0.545804
# [LightGBM] [Info] Start training from score -0.545804
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
from sklearn.metrics import accuracy_score

# Predictions
y_pred = ensemble_model.predict(X_test)

# Accuracy Score
accuracy = accuracy_score(y_test, y_pred)
print(f"Ensemble Model Accuracy: {accuracy * 100:.2f}%")
# Out:
# Ensemble Model Accuracy: 99.47%
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# Predictions on test data
y_pred = ensemble_model.predict(X_test)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

# Print Metrics
print(f"Accuracy: {accuracy * 100:.2f}%")
print(f"Precision: {precision * 100:.2f}%")
print(f"Recall: {recall * 100:.2f}%")
print(f"F1 Score: {f1 * 100:.2f}%")

# Detailed classification report
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['Safe Query', 'SQL Injection'], yticklabels=['Safe Query', 'SQL Injection'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# Individual Model Performance (for comparison)
models = ['Random Forest', 'XGBoost', 'LightGBM', 'Ensemble']
accuracies = [
    accuracy_score(y_test, rf_model.predict(X_test)),
    accuracy_score(y_test, xgb_model.predict(X_test)),
    accuracy_score(y_test, lgb_model.predict(X_test)),
    accuracy
]

# Visualization - Model Comparison
plt.figure(figsize=(8, 5))
sns.barplot(x=models, y=accuracies, palette="viridis")
plt.ylim(0.5, 1.0)
plt.ylabel("Accuracy Score")
plt.title("Comparison of Model Performance")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# Accuracy: 99.47%
# Precision: 99.47%
# Recall: 99.47%
# F1 Score: 99.47%
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      3893
#            1       1.00      0.99      0.99      2291
#
#     accuracy                           0.99      6184
#    macro avg       0.99      0.99      0.99      6184
# weighted avg       0.99      0.99      0.99      6184
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# <ipython-input-38-2f178bed6f10>:44: FutureWarning:
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# Function to get ensemble predictions (Average of model predictions)
def ensemble_predict(models, X):
    predictions = np.array([model.predict(X) for model in models])
    avg_prediction = np.mean(predictions, axis=0)
    return (avg_prediction > 0.5).astype(int)  # Convert probabilities to binary class labels

# List of models
models = [rnn_model, lstm_model, gru_model, cnn_model]

# Predict using ensemble
y_pred_ensemble = ensemble_predict(models, X_test)

# Calculate metrics
ensemble_accuracy = accuracy_score(y_test, y_pred_ensemble)
ensemble_precision = precision_score(y_test, y_pred_ensemble, average='weighted')
ensemble_recall = recall_score(y_test, y_pred_ensemble, average='weighted')
ensemble_f1 = f1_score(y_test, y_pred_ensemble, average='weighted')

# Print Metrics
print(f"Ensemble Model Accuracy: {ensemble_accuracy * 100:.2f}%")
print(f"Precision: {ensemble_precision * 100:.2f}%")
print(f"Recall: {ensemble_recall * 100:.2f}%")
print(f"F1 Score: {ensemble_f1 * 100:.2f}%")

# Classification Report
print("\nClassification Report:\n", classification_report(y_test, y_pred_ensemble))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_ensemble)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['Safe Query', 'SQL Injection'], yticklabels=['Safe Query', 'SQL Injection'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix for Ensemble Model")
plt.show()

# Individual Model Performance (for comparison)
model_names = ['RNN', 'LSTM', 'GRU', 'CNN', 'Ensemble']
accuracies = [
    accuracy_score(y_test, (rnn_model.predict(X_test) > 0.5).astype(int)),
    accuracy_score(y_test, (lstm_model.predict(X_test) > 0.5).astype(int)),
    accuracy_score(y_test, (gru_model.predict(X_test) > 0.5).astype(int)),
    accuracy_score(y_test, (cnn_model.predict(X_test) > 0.5).astype(int)),
    ensemble_accuracy
]

# Visualization - Model Comparison
plt.figure(figsize=(8, 5))
sns.barplot(x=model_names, y=accuracies, palette="viridis")
plt.ylim(0.5, 1.0)  # Adjust limits for better visualization
plt.ylabel("Accuracy Score")
plt.title("Comparison of Model Performance")
plt.show()
# Out:
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Ensemble Model Accuracy: 99.55%
# Precision: 99.55%
# Recall: 99.55%
# F1 Score: 99.55%
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3893
#            1       0.99      0.99      0.99      2291
#
#     accuracy                           1.00      6184
#    macro avg       0.99      1.00      1.00      6184
# weighted avg       1.00      1.00      1.00      6184
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# <ipython-input-39-6110d8f30290>:54: FutureWarning:
#
# ...

# %%
# Save each model
joblib.dump(rf_model, "rf_model.pkl")
joblib.dump(xgb_model, "xgb_model.pkl")
joblib.dump(lgb_model, "lgb_model.pkl")

# %%
import joblib


joblib.dump(rnn_model, "rnn_model.pkl")
joblib.dump(lstm_model, "lstm_model.pkl")
joblib.dump(gru_model, "gru_model.pkl")


print("✅ All models saved successfully!")
# Out:
# ✅ All models saved successfully!

# %%
from tensorflow.keras.models import save_model # Import the save_model function

save_model(rnn_model, "rnn_model.h5")
save_model(lstm_model, "lstm_model.h5")
save_model(gru_model, "gru_model.h5")
save_model(cnn_model, "cnn_model.h5")

# OR save in the newer .keras format (recommended for Keras 3+)
# save_model(rnn_model, "rnn_model.keras")
# save_model(lstm_model, "lstm_model.keras")
# save_model(gru_model, "gru_model.keras")
# save_model(cnn_model, "cnn_model.keras")

print("✅ All models resaved in proper Keras format!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ...

# %%
from tensorflow.keras.models import load_model
cnn_model = load_model("cnn_model.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
joblib.dump(cnn_model, "cnn_model.pkl")

# %%
import joblib

# Assuming 'ensemble_model' is your VotingClassifier instance from previous cells
joblib.dump(ensemble_model, "ensemble_ml.pkl")  # Change 'voting_classifier' to 'ensemble_model'

print("✅ ML Ensemble Model Saved Successfully!")
# Out:
# ✅ ML Ensemble Model Saved Successfully!

# %%
import numpy as np
import joblib
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import load_model # Import load_model

# Function to generate ensemble predictions
def ensemble_predict(models, X):
    predictions = np.array([model.predict(X) for model in models])
    avg_prediction = np.mean(predictions, axis=0)
    return (avg_prediction > 0.5).astype(int)

# Load trained models
rnn_model = joblib.load("rnn_model.pkl")
lstm_model = joblib.load("lstm_model.pkl")
gru_model = joblib.load("gru_model.pkl")
cnn_model = load_model("cnn_model.h5") # Use load_model to load the Keras model

# Define model list
models = [rnn_model, lstm_model, gru_model, cnn_model]

# Save the ensemble model
joblib.dump(models, "ensemble_model.pkl")

print("✅ Ensemble model saved successfully!")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Ensemble model saved successfully!
